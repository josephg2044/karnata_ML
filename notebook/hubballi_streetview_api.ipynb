# %%
import os
import pandas as pd
import requests
import random
import glob
from PIL import Image
import time
from io import BytesIO

# %%
key = 'YOUR_API_KEY'

# %%
# load datasets
data = pd.read_csv("../data/CS/Hubballi_Dhaward_Water_Consumption_All.csv")
data.head()
# Out:
#       rrno pzone  freq  permonthunitskl  sl_no    dma priority_group  \
# 0  46p0857  p1p2   5.0             63.8      4  H13D1      P1P1/P1P2
# 1  46po836  p1p2   NaN              NaN      6  H13D1      P1P1/P1P2
# 2  46po820  p1p2   NaN              NaN      8  H13D1      P1P1/P1P2
# 3  46p0855  p1p2   5.0             15.8     12  H13D1      P1P1/P1P2
# 4     3467  p1p2   NaN              NaN     14  H20D1      P1P1/P1P2
#
#   property_type   latitude  longitude  ... supply_in_hours pressure  \
# 0        Rented  15.353236  75.140630  ...              24     High
# 1        Rented  15.353527  75.140950  ...              24     High
# 2         Owned  15.354342  75.141685  ...              24     High
# 3        Rented  15.353131  75.141440  ...               5   Medium
# 4         Owned  15.352086  75.141110  ...               5     High
#
#       water_quality  other_connection_needed willingness_to_pay  \
# 0      Satisfactory                      Yes                NaN
# 1      Satisfactory                      Yes                NaN
# 2      Satisfactory                      Yes                NaN
# 3  Not Satisfactory                      Yes                Yes
# 4      Satisfactory                      Yes                NaN
#
#    water_storage_type sewage_connection_type rainwater_harvesting  \
# 0                Both  Under Ground Drainage                   No
# 1                Both  Under Ground Drainage                   No
# 2                Both  Under Ground Drainage                   No
# 3                Both  Under Ground Drainage                   No
# 4          No Storage                    NaN                  NaN
#
#   monthly_family_income ration_card
# 0                   NaN         NaN
# 1                   NaN         NaN
# 2                   NaN         NaN
# 3                10-20K         NaN
# 4                   NaN         NaN
#
# [5 rows x 30 columns]

# %%
data.shape
# Out:
# (35980, 30)

# %%
# Check which images already exist in the folder
satellite_dir = '../data/raw/Hubballi_Satellite'
street_dir = '../data/raw/Hubballi_Original'

satellite_filenames_exist = glob.glob1(satellite_dir, '*.jpg')
satellite_filenames_exist = {i.split('.jpg')[0] for i in satellite_filenames_exist}

street_filenames_exist = glob.glob1(street_dir, '*.jpg')
street_filenames_exist = {i.split('.jpg')[0] for i in street_filenames_exist}

print(f"Existing satellite images: {len(satellite_filenames_exist)}")
print(f"Existing street view images: {len(street_filenames_exist)}")
# Out:
# Existing satellite images: 23986
# Existing street view images: 17973

# %%
# Extract household id, longitude, and latitude from the dataframe
data_list = data.apply(lambda row: [row['sl_no'], row['latitude'], row['longitude']], axis=1).tolist()

# %%
from PIL import Image
import io

def crop_image(image_content):
    img = Image.open(io.BytesIO(image_content))
    width, height = img.size
    
    # Crop out bottom 20 pixels for both satellite and street view images
    cropped_img = img.crop((0, 0, width, height - 20))
    
    # Convert to RGB mode before returning
    return cropped_img.convert('RGB')

# extracting street view images
for data in data_list:
    FID, lon, lat = data[0], data[1], data[2]
    # zoom for satellite image
    zoom = 30
    # resolution for satellite image
    res1 = 640
    res2 = 660
    try:
        # download satellite image
        if '{}'.format(FID) in satellite_filenames_exist:
            print('Satellite image {} has been downloaded'.format(FID))
        else:
            sat_url = 'https://maps.googleapis.com/maps/api/staticmap?center={},{}&maptype=satellite&zoom={}&size={}x{}&key={}'.format(lon, lat, zoom, res1, res2, key)
            response = requests.get(sat_url)
            img = response.content
            if len(img) > 100:
                cropped_img = crop_image(img)
                cropped_img.save('../data/raw/Hubballi_Satellite/{}.jpg'.format(FID), 'JPEG')
                print('Successfully downloaded and cropped satellite image {}'.format(FID))
            else:
                print('Satellite downloading error {}'.format(FID))    
        
        # download streetview images
        if '{}'.format(FID) in street_filenames_exist:
            print('Street view {} has been downloaded'.format(FID))
        else:
            street_url = 'https://maps.googleapis.com/maps/api/streetview?size=600x420&location={},{}&fov=90&pitch=0&key={}'.format(lon, lat, key)
            status_url = 'https://maps.googleapis.com/maps/api/streetview/metadata?size=600x400&location={},{}&fov=90&pitch=0&key={}='.format(lon, lat, key)
            # check if streetview image exists, otherwise skip to next image
            if requests.get(status_url).json()['status'] == 'ZERO_RESULTS':
                print(f"No image exists for {FID}. Image skipped.")
                continue
            response = requests.get(street_url)
            img = response.content
            if len(img) > 100:
                cropped_img = crop_image(img)
                cropped_img.save('../data/raw/Hubballi_Original/{}.jpg'.format(FID), 'JPEG')
                print('Successfully downloaded and cropped {}'.format(FID))
            else:
                print('Streetview downloading error {}'.format(FID))
            
    except Exception as e:
        print('Error warning. Execution stopped!')
        print(f'Error details: {str(e)}')
        break
# Out:
# Satellite image 4 has been downloaded
# No image exists for 4. Image skipped.
# Successfully downloaded and cropped satellite image 6
# No image exists for 6. Image skipped.
# Successfully downloaded and cropped satellite image 8
# Successfully downloaded and cropped 8
# Satellite image 12 has been downloaded
# No image exists for 12. Image skipped.
# Satellite image 14 has been downloaded
# No image exists for 14. Image skipped.
# Satellite image 27 has been downloaded
# No image exists for 27. Image skipped.
# Satellite image 28 has been downloaded
# No image exists for 28. Image skipped.
# Satellite image 33 has been downloaded
# No image exists for 33. Image skipped.
# Successfully downloaded and cropped satellite image 71
# Successfully downloaded and cropped 71
# Successfully downloaded and cropped satellite image 72
# Successfully downloaded and cropped 72
# Successfully downloaded and cropped satellite image 73
# Successfully downloaded and cropped 73
# Satellite image 75 has been downloaded
# No image exists for 75. Image skipped.
# Successfully downloaded and cropped satellite image 76
# No image exists for 76. Image skipped.
# Satellite image 77 has been downloaded
# Street view 77 has been downloaded
# Satellite image 78 has been downloaded
# Street view 78 has been downloaded
# Satellite image 79 has been downloaded
# No image exists for 79. Image skipped.
# Satellite image 80 has been downloaded
# No image exists for 80. Image skipped.
# Successfully downloaded and cropped satellite image 81
# No image exists for 81. Image skipped.
# Successfully downloaded and cropped satellite image 82
# No image exists for 82. Image skipped.
# Satellite image 84 has been downloaded
# Street view 84 has been downloaded
# Successfully downloaded and cropped satellite image 86
# No image exists for 86. Image skipped.
# Successfully downloaded and cropped satellite image 87
# No image exists for 87. Image skipped.
# Satellite image 89 has been downloaded
# No image exists for 89. Image skipped.
# Satellite image 90 has been downloaded
# No image exists for 90. Image skipped.
# Successfully downloaded and cropped satellite image 91
# No image exists for 91. Image skipped.
# Successfully downloaded and cropped satellite image 92
# No image exists for 92. Image skipped.
# Successfully downloaded and cropped satellite image 93
# No image exists for 93. Image skipped.
# Successfully downloaded and cropped satellite image 94
# No image exists for 94. Image skipped.
# Successfully downloaded and cropped satellite image 484
# Successfully downloaded and cropped 484
# Successfully downloaded and cropped satellite image 485
# Successfully downloaded and cropped 485
# Successfully downloaded and cropped satellite image 486
# Successfully downloaded and cropped 486
# Successfully downloaded and cropped satellite image 488
# Successfully downloaded and cropped 488
# Successfully downloaded and cropped satellite image 489
# Successfully downloaded and cropped 489
# Successfully downloaded and cropped satellite image 490
# Successfully downloaded and cropped 490
# Successfully downloaded and cropped satellite image 491
# Successfully downloaded and cropped 491
# Successfully downloaded and cropped satellite image 492
# Successfully downloaded and cropped 492
# Successfully downloaded and cropped satellite image 493
# Successfully downloaded and cropped 493
# Successfully downloaded and cropped satellite image 494
# Successfully downloaded and cropped 494
# Successfully downloaded and cropped satellite image 495
# Successfully downloaded and cropped 495
# Successfully downloaded and cropped satellite image 496
# Successfully downloaded and cropped 496
# Successfully downloaded and cropped satellite image 497
# Successfully downloaded and cropped 497
# Successfully downloaded and cropped satellite image 498
# Successfully downloaded and cropped 498
# Successfully downloaded and cropped satellite image 499
# Successfully downloaded and cropped 499
# Successfully downloaded and cropped satellite image 500
# Successfully downloaded and cropped 500
# Successfully downloaded and cropped satellite image 501
# Successfully downloaded and cropped 501
# Successfully downloaded and cropped satellite image 502
# Successfully downloaded and cropped 502
# Successfully downloaded and cropped satellite image 503
# Successfully downloaded and cropped 503
# Successfully downloaded and cropped satellite image 504
# Successfully downloaded and cropped 504
# Successfully downloaded and cropped satellite image 505
# Successfully downloaded and cropped 505
# Successfully downloaded and cropped satellite image 506
# Successfully downloaded and cropped 506
# Successfully downloaded and cropped satellite image 507
# Successfully downloaded and cropped 507
# Successfully downloaded and cropped satellite image 508
# Successfully downloaded and cropped 508
# Successfully downloaded and cropped satellite image 509
# Successfully downloaded and cropped 509
# Successfully downloaded and cropped satellite image 510
# Successfully downloaded and cropped 510
# Successfully downloaded and cropped satellite image 511
# Successfully downloaded and cropped 511
# Successfully downloaded and cropped satellite image 512
# Successfully downloaded and cropped 512
# Successfully downloaded and cropped satellite image 513
# Successfully downloaded and cropped 513
# Successfully downloaded and cropped satellite image 514
# Successfully downloaded and cropped 514
# Successfully downloaded and cropped satellite image 515
# Successfully downloaded and cropped 515
# Successfully downloaded and cropped satellite image 516
# Successfully downloaded and cropped 516
# Successfully downloaded and cropped satellite image 518
# Successfully downloaded and cropped 518
# Successfully downloaded and cropped satellite image 519
# Successfully downloaded and cropped 519
# Successfully downloaded and cropped satellite image 520
# Successfully downloaded and cropped 520
# Successfully downloaded and cropped satellite image 521
# Successfully downloaded and cropped 521
# Successfully downloaded and cropped satellite image 522
# Successfully downloaded and cropped 522
# Successfully downloaded and cropped satellite image 523
# Successfully downloaded and cropped 523
# Successfully downloaded and cropped satellite image 524
# Successfully downloaded and cropped 524
# Successfully downloaded and cropped satellite image 525
# Successfully downloaded and cropped 525
# Successfully downloaded and cropped satellite image 526
# Successfully downloaded and cropped 526
# Successfully downloaded and cropped satellite image 527
# Successfully downloaded and cropped 527
# Successfully downloaded and cropped satellite image 528
# Successfully downloaded and cropped 528
# Successfully downloaded and cropped satellite image 529
# Successfully downloaded and cropped 529
# Successfully downloaded and cropped satellite image 530
# Successfully downloaded and cropped 530
# Successfully downloaded and cropped satellite image 531
# Successfully downloaded and cropped 531
# Successfully downloaded and cropped satellite image 532
# Successfully downloaded and cropped 532
# Successfully downloaded and cropped satellite image 533
# Successfully downloaded and cropped 533
# Successfully downloaded and cropped satellite image 534
# Successfully downloaded and cropped 534
# Successfully downloaded and cropped satellite image 535
# Successfully downloaded and cropped 535
# Successfully downloaded and cropped satellite image 536
# Successfully downloaded and cropped 536
# Successfully downloaded and cropped satellite image 537
# Successfully downloaded and cropped 537
# Successfully downloaded and cropped satellite image 538
# Successfully downloaded and cropped 538
# Successfully downloaded and cropped satellite image 539
# Successfully downloaded and cropped 539
# Successfully downloaded and cropped satellite image 540
# Successfully downloaded and cropped 540
# Successfully downloaded and cropped satellite image 541
# Successfully downloaded and cropped 541
# Successfully downloaded and cropped satellite image 542
# Successfully downloaded and cropped 542
# Successfully downloaded and cropped satellite image 543
# Successfully downloaded and cropped 543
# Successfully downloaded and cropped satellite image 544
# Successfully downloaded and cropped 544
# Successfully downloaded and cropped satellite image 545
# Successfully downloaded and cropped 545
# Successfully downloaded and cropped satellite image 546
# Successfully downloaded and cropped 546
# Successfully downloaded and cropped satellite image 547
# Successfully downloaded and cropped 547
# Successfully downloaded and cropped satellite image 548
# Successfully downloaded and cropped 548
# Successfully downloaded and cropped satellite image 549
# Successfully downloaded and cropped 549
# Successfully downloaded and cropped satellite image 550
# Successfully downloaded and cropped 550
# Successfully downloaded and cropped satellite image 551
# Successfully downloaded and cropped 551
# Successfully downloaded and cropped satellite image 552
# Successfully downloaded and cropped 552
# Successfully downloaded and cropped satellite image 553
# Successfully downloaded and cropped 553
# Successfully downloaded and cropped satellite image 554
# Successfully downloaded and cropped 554
# Successfully downloaded and cropped satellite image 555
# Successfully downloaded and cropped 555
# Successfully downloaded and cropped satellite image 556
# Successfully downloaded and cropped 556
# Successfully downloaded and cropped satellite image 557
# Successfully downloaded and cropped 557
# Successfully downloaded and cropped satellite image 558
# Successfully downloaded and cropped 558
# Successfully downloaded and cropped satellite image 559
# Successfully downloaded and cropped 559
# Successfully downloaded and cropped satellite image 560
# Successfully downloaded and cropped 560
# Successfully downloaded and cropped satellite image 561
# Successfully downloaded and cropped 561
# Successfully downloaded and cropped satellite image 562
# Successfully downloaded and cropped 562
# Successfully downloaded and cropped satellite image 563
# Successfully downloaded and cropped 563
# Successfully downloaded and cropped satellite image 564
# Successfully downloaded and cropped 564
# Successfully downloaded and cropped satellite image 565
# Successfully downloaded and cropped 565
# Successfully downloaded and cropped satellite image 566
# Successfully downloaded and cropped 566
# Successfully downloaded and cropped satellite image 567
# Successfully downloaded and cropped 567
# Successfully downloaded and cropped satellite image 568
# Successfully downloaded and cropped 568
# Successfully downloaded and cropped satellite image 569
# Successfully downloaded and cropped 569
# Successfully downloaded and cropped satellite image 570
# Successfully downloaded and cropped 570
# Successfully downloaded and cropped satellite image 571
# Successfully downloaded and cropped 571
# Successfully downloaded and cropped satellite image 572
# Successfully downloaded and cropped 572
# Successfully downloaded and cropped satellite image 573
# Successfully downloaded and cropped 573
# Successfully downloaded and cropped satellite image 575
# Successfully downloaded and cropped 575
# Successfully downloaded and cropped satellite image 576
# Successfully downloaded and cropped 576
# Successfully downloaded and cropped satellite image 577
# Successfully downloaded and cropped 577
# Successfully downloaded and cropped satellite image 578
# Successfully downloaded and cropped 578
# Successfully downloaded and cropped satellite image 579
# Successfully downloaded and cropped 579
# Successfully downloaded and cropped satellite image 580
# Successfully downloaded and cropped 580
# Successfully downloaded and cropped satellite image 581
# Successfully downloaded and cropped 581
# Successfully downloaded and cropped satellite image 582
# Successfully downloaded and cropped 582
# Successfully downloaded and cropped satellite image 583
# Successfully downloaded and cropped 583
# Successfully downloaded and cropped satellite image 584
# Successfully downloaded and cropped 584
# Successfully downloaded and cropped satellite image 585
# Successfully downloaded and cropped 585
# Successfully downloaded and cropped satellite image 586
# Successfully downloaded and cropped 586
# Successfully downloaded and cropped satellite image 587
# Successfully downloaded and cropped 587
# Successfully downloaded and cropped satellite image 588
# Successfully downloaded and cropped 588
# Successfully downloaded and cropped satellite image 589
# Successfully downloaded and cropped 589
# Successfully downloaded and cropped satellite image 590
# No image exists for 590. Image skipped.
# Successfully downloaded and cropped satellite image 591
# Successfully downloaded and cropped 591
# Successfully downloaded and cropped satellite image 592
# Successfully downloaded and cropped 592
# Successfully downloaded and cropped satellite image 593
# No image exists for 593. Image skipped.
# Successfully downloaded and cropped satellite image 594
# No image exists for 594. Image skipped.
# Successfully downloaded and cropped satellite image 595
# Successfully downloaded and cropped 595
# Successfully downloaded and cropped satellite image 596
# Successfully downloaded and cropped 596
# Successfully downloaded and cropped satellite image 597
# Successfully downloaded and cropped 597
# Successfully downloaded and cropped satellite image 598
# No image exists for 598. Image skipped.
# Successfully downloaded and cropped satellite image 599
# No image exists for 599. Image skipped.
# Successfully downloaded and cropped satellite image 600
# No image exists for 600. Image skipped.
# Successfully downloaded and cropped satellite image 601
# No image exists for 601. Image skipped.
# Successfully downloaded and cropped satellite image 602
# No image exists for 602. Image skipped.
# Successfully downloaded and cropped satellite image 603
# No image exists for 603. Image skipped.
# Successfully downloaded and cropped satellite image 604
# No image exists for 604. Image skipped.
# Successfully downloaded and cropped satellite image 605
# Successfully downloaded and cropped 605
# Successfully downloaded and cropped satellite image 606
# Successfully downloaded and cropped 606
# Successfully downloaded and cropped satellite image 607
# No image exists for 607. Image skipped.
# Successfully downloaded and cropped satellite image 608
# No image exists for 608. Image skipped.
# Successfully downloaded and cropped satellite image 609
# No image exists for 609. Image skipped.
# Successfully downloaded and cropped satellite image 610
# No image exists for 610. Image skipped.
# Successfully downloaded and cropped satellite image 611
# No image exists for 611. Image skipped.
# Successfully downloaded and cropped satellite image 612
# Successfully downloaded and cropped 612
# Successfully downloaded and cropped satellite image 613
# Successfully downloaded and cropped 613
# Successfully downloaded and cropped satellite image 614
# Successfully downloaded and cropped 614
# Successfully downloaded and cropped satellite image 615
# Successfully downloaded and cropped 615
# Successfully downloaded and cropped satellite image 616
# Successfully downloaded and cropped 616
# Successfully downloaded and cropped satellite image 617
# Successfully downloaded and cropped 617
# Successfully downloaded and cropped satellite image 618
# Successfully downloaded and cropped 618
# Successfully downloaded and cropped satellite image 619
# Successfully downloaded and cropped 619
# Successfully downloaded and cropped satellite image 620
# Successfully downloaded and cropped 620
# Successfully downloaded and cropped satellite image 621
# Successfully downloaded and cropped 621
# Successfully downloaded and cropped satellite image 622
# Successfully downloaded and cropped 622
# Successfully downloaded and cropped satellite image 623
# Successfully downloaded and cropped 623
# Successfully downloaded and cropped satellite image 624
# Successfully downloaded and cropped 624
# Successfully downloaded and cropped satellite image 625
# Successfully downloaded and cropped 625
# Successfully downloaded and cropped satellite image 627
# Successfully downloaded and cropped 627
# Successfully downloaded and cropped satellite image 628
# Successfully downloaded and cropped 628
# Successfully downloaded and cropped satellite image 629
# Successfully downloaded and cropped 629
# Successfully downloaded and cropped satellite image 630
# Successfully downloaded and cropped 630
# Successfully downloaded and cropped satellite image 631
# Successfully downloaded and cropped 631
# Successfully downloaded and cropped satellite image 632
# Successfully downloaded and cropped 632
# Successfully downloaded and cropped satellite image 633
# Successfully downloaded and cropped 633
# Successfully downloaded and cropped satellite image 634
# Successfully downloaded and cropped 634
# Successfully downloaded and cropped satellite image 635
# Successfully downloaded and cropped 635
# Successfully downloaded and cropped satellite image 636
# Successfully downloaded and cropped 636
# Successfully downloaded and cropped satellite image 637
# Successfully downloaded and cropped 637
# Successfully downloaded and cropped satellite image 638
# Successfully downloaded and cropped 638
# Successfully downloaded and cropped satellite image 639
# Successfully downloaded and cropped 639
# Successfully downloaded and cropped satellite image 640
# Successfully downloaded and cropped 640
# Successfully downloaded and cropped satellite image 641
# Successfully downloaded and cropped 641
# Successfully downloaded and cropped satellite image 642
# Successfully downloaded and cropped 642
# Successfully downloaded and cropped satellite image 643
# Successfully downloaded and cropped 643
# Successfully downloaded and cropped satellite image 644
# Successfully downloaded and cropped 644
# Successfully downloaded and cropped satellite image 645
# Successfully downloaded and cropped 645
# Successfully downloaded and cropped satellite image 646
# Successfully downloaded and cropped 646
# Successfully downloaded and cropped satellite image 647
# Successfully downloaded and cropped 647
# Successfully downloaded and cropped satellite image 648
# Successfully downloaded and cropped 648
# Successfully downloaded and cropped satellite image 649
# Successfully downloaded and cropped 649
# Successfully downloaded and cropped satellite image 650
# Successfully downloaded and cropped 650
# Successfully downloaded and cropped satellite image 651
# Successfully downloaded and cropped 651
# Successfully downloaded and cropped satellite image 652
# Successfully downloaded and cropped 652
# Successfully downloaded and cropped satellite image 653
# Successfully downloaded and cropped 653
# Successfully downloaded and cropped satellite image 654
# Successfully downloaded and cropped 654
# Successfully downloaded and cropped satellite image 655
# Successfully downloaded and cropped 655
# Successfully downloaded and cropped satellite image 656
# Successfully downloaded and cropped 656
# Successfully downloaded and cropped satellite image 657
# No image exists for 657. Image skipped.
# Successfully downloaded and cropped satellite image 658
# Successfully downloaded and cropped 658
# Successfully downloaded and cropped satellite image 659
# No image exists for 659. Image skipped.
# Successfully downloaded and cropped satellite image 660
# Successfully downloaded and cropped 660
# Successfully downloaded and cropped satellite image 661
# Successfully downloaded and cropped 661
# Successfully downloaded and cropped satellite image 662
# Successfully downloaded and cropped 662
# Successfully downloaded and cropped satellite image 663
# Successfully downloaded and cropped 663
# Successfully downloaded and cropped satellite image 664
# Successfully downloaded and cropped 664
# Successfully downloaded and cropped satellite image 665
# Successfully downloaded and cropped 665
# Successfully downloaded and cropped satellite image 666
# Successfully downloaded and cropped 666
# Successfully downloaded and cropped satellite image 667
# Successfully downloaded and cropped 667
# Successfully downloaded and cropped satellite image 668
# Successfully downloaded and cropped 668
# Successfully downloaded and cropped satellite image 669
# Successfully downloaded and cropped 669
# Successfully downloaded and cropped satellite image 670
# Successfully downloaded and cropped 670
# Successfully downloaded and cropped satellite image 671
# Successfully downloaded and cropped 671
# Successfully downloaded and cropped satellite image 672
# Successfully downloaded and cropped 672
# Successfully downloaded and cropped satellite image 673
# Successfully downloaded and cropped 673
# Successfully downloaded and cropped satellite image 674
# Successfully downloaded and cropped 674
# Successfully downloaded and cropped satellite image 675
# Successfully downloaded and cropped 675
# Successfully downloaded and cropped satellite image 676
# Successfully downloaded and cropped 676
# Successfully downloaded and cropped satellite image 677
# Successfully downloaded and cropped 677
# Successfully downloaded and cropped satellite image 678
# Successfully downloaded and cropped 678
# Successfully downloaded and cropped satellite image 679
# Successfully downloaded and cropped 679
# Successfully downloaded and cropped satellite image 680
# Successfully downloaded and cropped 680
# Successfully downloaded and cropped satellite image 681
# Successfully downloaded and cropped 681
# Successfully downloaded and cropped satellite image 682
# Successfully downloaded and cropped 682
# Successfully downloaded and cropped satellite image 683
# Successfully downloaded and cropped 683
# Successfully downloaded and cropped satellite image 684
# Successfully downloaded and cropped 684
# Successfully downloaded and cropped satellite image 685
# Successfully downloaded and cropped 685
# Successfully downloaded and cropped satellite image 686
# Successfully downloaded and cropped 686
# Successfully downloaded and cropped satellite image 687
# Successfully downloaded and cropped 687
# Successfully downloaded and cropped satellite image 688
# Successfully downloaded and cropped 688
# Successfully downloaded and cropped satellite image 689
# Successfully downloaded and cropped 689
# Successfully downloaded and cropped satellite image 690
# Successfully downloaded and cropped 690
# Successfully downloaded and cropped satellite image 691
# Successfully downloaded and cropped 691
# Successfully downloaded and cropped satellite image 692
# Successfully downloaded and cropped 692
# Successfully downloaded and cropped satellite image 693
# Successfully downloaded and cropped 693
# Successfully downloaded and cropped satellite image 694
# Successfully downloaded and cropped 694
# Successfully downloaded and cropped satellite image 695
# Successfully downloaded and cropped 695
# Successfully downloaded and cropped satellite image 696
# Successfully downloaded and cropped 696
# Successfully downloaded and cropped satellite image 697
# Successfully downloaded and cropped 697
# Successfully downloaded and cropped satellite image 698
# Successfully downloaded and cropped 698
# Successfully downloaded and cropped satellite image 699
# Successfully downloaded and cropped 699
# Successfully downloaded and cropped satellite image 700
# Successfully downloaded and cropped 700
# Successfully downloaded and cropped satellite image 701
# Successfully downloaded and cropped 701
# Successfully downloaded and cropped satellite image 702
# Successfully downloaded and cropped 702
# Successfully downloaded and cropped satellite image 703
# Successfully downloaded and cropped 703
# Successfully downloaded and cropped satellite image 704
# Successfully downloaded and cropped 704
# Successfully downloaded and cropped satellite image 705
# Successfully downloaded and cropped 705
# Successfully downloaded and cropped satellite image 706
# Successfully downloaded and cropped 706
# Successfully downloaded and cropped satellite image 707
# Successfully downloaded and cropped 707
# Successfully downloaded and cropped satellite image 708
# Successfully downloaded and cropped 708
# Successfully downloaded and cropped satellite image 709
# Successfully downloaded and cropped 709
# Successfully downloaded and cropped satellite image 710
# Successfully downloaded and cropped 710
# Successfully downloaded and cropped satellite image 711
# Successfully downloaded and cropped 711
# Successfully downloaded and cropped satellite image 712
# Successfully downloaded and cropped 712
# Successfully downloaded and cropped satellite image 713
# Successfully downloaded and cropped 713
# Successfully downloaded and cropped satellite image 714
# Successfully downloaded and cropped 714
# Successfully downloaded and cropped satellite image 964
# Successfully downloaded and cropped 964
# Satellite image 969 has been downloaded
# Street view 969 has been downloaded
# Satellite image 970 has been downloaded
# Street view 970 has been downloaded
# Satellite image 971 has been downloaded
# Street view 971 has been downloaded
# Satellite image 972 has been downloaded
# Street view 972 has been downloaded
# Satellite image 973 has been downloaded
# Street view 973 has been downloaded
# Satellite image 974 has been downloaded
# Street view 974 has been downloaded
# Satellite image 975 has been downloaded
# Street view 975 has been downloaded
# Satellite image 976 has been downloaded
# Street view 976 has been downloaded
# Satellite image 977 has been downloaded
# Street view 977 has been downloaded
# Satellite image 978 has been downloaded
# Street view 978 has been downloaded
# Satellite image 979 has been downloaded
# Street view 979 has been downloaded
# Satellite image 980 has been downloaded
# Street view 980 has been downloaded
# Satellite image 981 has been downloaded
# Street view 981 has been downloaded
# Successfully downloaded and cropped satellite image 982
# Successfully downloaded and cropped 982
# Successfully downloaded and cropped satellite image 983
# Successfully downloaded and cropped 983
# Satellite image 984 has been downloaded
# Street view 984 has been downloaded
# Successfully downloaded and cropped satellite image 985
# Successfully downloaded and cropped 985
# Successfully downloaded and cropped satellite image 986
# Successfully downloaded and cropped 986
# Successfully downloaded and cropped satellite image 987
# Successfully downloaded and cropped 987
# Satellite image 988 has been downloaded
# Street view 988 has been downloaded
# Successfully downloaded and cropped satellite image 989
# Successfully downloaded and cropped 989
# Successfully downloaded and cropped satellite image 990
# Successfully downloaded and cropped 990
# Satellite image 991 has been downloaded
# Street view 991 has been downloaded
# Satellite image 992 has been downloaded
# Street view 992 has been downloaded
# Satellite image 993 has been downloaded
# Street view 993 has been downloaded
# Satellite image 994 has been downloaded
# Street view 994 has been downloaded
# Satellite image 995 has been downloaded
# Street view 995 has been downloaded
# Satellite image 996 has been downloaded
# Street view 996 has been downloaded
# Successfully downloaded and cropped satellite image 997
# Successfully downloaded and cropped 997
# Satellite image 998 has been downloaded
# Street view 998 has been downloaded
# Satellite image 999 has been downloaded
# Street view 999 has been downloaded
# Satellite image 1000 has been downloaded
# Street view 1000 has been downloaded
# Satellite image 1001 has been downloaded
# Street view 1001 has been downloaded
# Satellite image 1002 has been downloaded
# Street view 1002 has been downloaded
# Satellite image 1003 has been downloaded
# Street view 1003 has been downloaded
# Satellite image 1005 has been downloaded
# Street view 1005 has been downloaded
# Satellite image 1006 has been downloaded
# Street view 1006 has been downloaded
# Satellite image 1007 has been downloaded
# Street view 1007 has been downloaded
# Satellite image 1008 has been downloaded
# Street view 1008 has been downloaded
# Satellite image 1010 has been downloaded
# Street view 1010 has been downloaded
# Satellite image 1011 has been downloaded
# Street view 1011 has been downloaded
# Satellite image 1012 has been downloaded
# Street view 1012 has been downloaded
# Satellite image 1013 has been downloaded
# Street view 1013 has been downloaded
# Satellite image 1014 has been downloaded
# Street view 1014 has been downloaded
# Satellite image 1015 has been downloaded
# Street view 1015 has been downloaded
# Satellite image 1016 has been downloaded
# Street view 1016 has been downloaded
# Satellite image 1017 has been downloaded
# Street view 1017 has been downloaded
# Satellite image 1018 has been downloaded
# Street view 1018 has been downloaded
# Satellite image 1019 has been downloaded
# Street view 1019 has been downloaded
# Satellite image 1020 has been downloaded
# Street view 1020 has been downloaded
# Satellite image 1021 has been downloaded
# Street view 1021 has been downloaded
# Satellite image 1022 has been downloaded
# Street view 1022 has been downloaded
# Satellite image 1023 has been downloaded
# Street view 1023 has been downloaded
# Satellite image 1024 has been downloaded
# Street view 1024 has been downloaded
# Satellite image 1025 has been downloaded
# Street view 1025 has been downloaded
# Satellite image 1026 has been downloaded
# Street view 1026 has been downloaded
# Satellite image 1027 has been downloaded
# Street view 1027 has been downloaded
# Satellite image 1028 has been downloaded
# Street view 1028 has been downloaded
# Satellite image 1029 has been downloaded
# Street view 1029 has been downloaded
# Satellite image 1030 has been downloaded
# Street view 1030 has been downloaded
# Satellite image 1031 has been downloaded
# Street view 1031 has been downloaded
# Satellite image 1032 has been downloaded
# Street view 1032 has been downloaded
# Satellite image 1033 has been downloaded
# Street view 1033 has been downloaded
# Satellite image 1034 has been downloaded
# Street view 1034 has been downloaded
# Satellite image 1035 has been downloaded
# Street view 1035 has been downloaded
# Satellite image 1036 has been downloaded
# Street view 1036 has been downloaded
# Satellite image 1037 has been downloaded
# Street view 1037 has been downloaded
# Satellite image 1038 has been downloaded
# Street view 1038 has been downloaded
# Satellite image 1039 has been downloaded
# Street view 1039 has been downloaded
# Satellite image 1040 has been downloaded
# Street view 1040 has been downloaded
# Satellite image 1042 has been downloaded
# Street view 1042 has been downloaded
# Satellite image 1043 has been downloaded
# Street view 1043 has been downloaded
# Satellite image 1044 has been downloaded
# Street view 1044 has been downloaded
# Satellite image 1045 has been downloaded
# Street view 1045 has been downloaded
# Satellite image 1046 has been downloaded
# Street view 1046 has been downloaded
# Satellite image 1047 has been downloaded
# Street view 1047 has been downloaded
# Satellite image 1048 has been downloaded
# Street view 1048 has been downloaded
# Satellite image 1049 has been downloaded
# Street view 1049 has been downloaded
# Satellite image 1050 has been downloaded
# Street view 1050 has been downloaded
# Satellite image 1051 has been downloaded
# Street view 1051 has been downloaded
# Satellite image 1052 has been downloaded
# Street view 1052 has been downloaded
# Satellite image 1053 has been downloaded
# Street view 1053 has been downloaded
# Satellite image 1054 has been downloaded
# Street view 1054 has been downloaded
# Satellite image 1055 has been downloaded
# Street view 1055 has been downloaded
# Satellite image 1056 has been downloaded
# Street view 1056 has been downloaded
# Satellite image 1057 has been downloaded
# Street view 1057 has been downloaded
# Satellite image 1058 has been downloaded
# Street view 1058 has been downloaded
# Satellite image 1059 has been downloaded
# Street view 1059 has been downloaded
# Satellite image 1060 has been downloaded
# Street view 1060 has been downloaded
# Satellite image 1061 has been downloaded
# Street view 1061 has been downloaded
# Satellite image 1062 has been downloaded
# Street view 1062 has been downloaded
# Satellite image 1063 has been downloaded
# Street view 1063 has been downloaded
# Satellite image 1064 has been downloaded
# Street view 1064 has been downloaded
# Satellite image 1065 has been downloaded
# Street view 1065 has been downloaded
# Satellite image 1066 has been downloaded
# Street view 1066 has been downloaded
# Satellite image 1067 has been downloaded
# Street view 1067 has been downloaded
# Satellite image 1068 has been downloaded
# Street view 1068 has been downloaded
# Satellite image 1069 has been downloaded
# Street view 1069 has been downloaded
# Satellite image 1070 has been downloaded
# Street view 1070 has been downloaded
# Satellite image 1071 has been downloaded
# Street view 1071 has been downloaded
# Satellite image 1072 has been downloaded
# Street view 1072 has been downloaded
# Satellite image 1073 has been downloaded
# Street view 1073 has been downloaded
# Satellite image 1074 has been downloaded
# Street view 1074 has been downloaded
# Satellite image 1075 has been downloaded
# Street view 1075 has been downloaded
# Satellite image 1076 has been downloaded
# Street view 1076 has been downloaded
# Satellite image 1077 has been downloaded
# Street view 1077 has been downloaded
# Satellite image 1078 has been downloaded
# No image exists for 1078. Image skipped.
# Satellite image 1079 has been downloaded
# No image exists for 1079. Image skipped.
# Satellite image 1080 has been downloaded
# No image exists for 1080. Image skipped.
# Satellite image 1081 has been downloaded
# No image exists for 1081. Image skipped.
# Satellite image 1082 has been downloaded
# No image exists for 1082. Image skipped.
# Satellite image 1083 has been downloaded
# No image exists for 1083. Image skipped.
# Satellite image 1084 has been downloaded
# No image exists for 1084. Image skipped.
# Satellite image 1085 has been downloaded
# No image exists for 1085. Image skipped.
# Satellite image 1086 has been downloaded
# Street view 1086 has been downloaded
# Satellite image 1087 has been downloaded
# Street view 1087 has been downloaded
# Satellite image 1088 has been downloaded
# Street view 1088 has been downloaded
# Satellite image 1089 has been downloaded
# No image exists for 1089. Image skipped.
# Satellite image 1090 has been downloaded
# No image exists for 1090. Image skipped.
# Satellite image 1091 has been downloaded
# No image exists for 1091. Image skipped.
# Satellite image 1092 has been downloaded
# Street view 1092 has been downloaded
# Satellite image 1093 has been downloaded
# Street view 1093 has been downloaded
# Satellite image 1094 has been downloaded
# Street view 1094 has been downloaded
# Satellite image 1095 has been downloaded
# No image exists for 1095. Image skipped.
# Satellite image 1096 has been downloaded
# Street view 1096 has been downloaded
# Satellite image 1097 has been downloaded
# Street view 1097 has been downloaded
# Satellite image 1098 has been downloaded
# Street view 1098 has been downloaded
# Satellite image 1099 has been downloaded
# No image exists for 1099. Image skipped.
# Satellite image 1100 has been downloaded
# No image exists for 1100. Image skipped.
# Satellite image 1101 has been downloaded
# No image exists for 1101. Image skipped.
# Satellite image 1102 has been downloaded
# No image exists for 1102. Image skipped.
# Satellite image 1103 has been downloaded
# No image exists for 1103. Image skipped.
# Satellite image 1104 has been downloaded
# No image exists for 1104. Image skipped.
# Satellite image 1105 has been downloaded
# Street view 1105 has been downloaded
# Satellite image 1106 has been downloaded
# No image exists for 1106. Image skipped.
# Satellite image 1107 has been downloaded
# Street view 1107 has been downloaded
# Satellite image 1108 has been downloaded
# Street view 1108 has been downloaded
# Satellite image 1109 has been downloaded
# Street view 1109 has been downloaded
# Satellite image 1110 has been downloaded
# Street view 1110 has been downloaded
# Satellite image 1111 has been downloaded
# No image exists for 1111. Image skipped.
# Satellite image 1112 has been downloaded
# No image exists for 1112. Image skipped.
# Satellite image 1113 has been downloaded
# Street view 1113 has been downloaded
# Satellite image 1114 has been downloaded
# Street view 1114 has been downloaded
# Satellite image 1115 has been downloaded
# Street view 1115 has been downloaded
# Satellite image 1116 has been downloaded
# Street view 1116 has been downloaded
# Satellite image 1117 has been downloaded
# Street view 1117 has been downloaded
# Satellite image 1118 has been downloaded
# No image exists for 1118. Image skipped.
# Satellite image 1119 has been downloaded
# No image exists for 1119. Image skipped.
# Satellite image 1120 has been downloaded
# No image exists for 1120. Image skipped.
# Satellite image 1121 has been downloaded
# No image exists for 1121. Image skipped.
# Satellite image 1122 has been downloaded
# No image exists for 1122. Image skipped.
# Satellite image 1123 has been downloaded
# No image exists for 1123. Image skipped.
# Satellite image 1124 has been downloaded
# No image exists for 1124. Image skipped.
# Satellite image 1125 has been downloaded
# No image exists for 1125. Image skipped.
# Satellite image 1126 has been downloaded
# Street view 1126 has been downloaded
# Satellite image 1127 has been downloaded
# Street view 1127 has been downloaded
# Satellite image 1128 has been downloaded
# Street view 1128 has been downloaded
# Satellite image 1129 has been downloaded
# Street view 1129 has been downloaded
# Satellite image 1130 has been downloaded
# No image exists for 1130. Image skipped.
# Satellite image 1131 has been downloaded
# No image exists for 1131. Image skipped.
# Satellite image 1132 has been downloaded
# No image exists for 1132. Image skipped.
# Satellite image 1133 has been downloaded
# Street view 1133 has been downloaded
# Satellite image 1134 has been downloaded
# Street view 1134 has been downloaded
# Satellite image 1135 has been downloaded
# Street view 1135 has been downloaded
# Satellite image 1136 has been downloaded
# Street view 1136 has been downloaded
# Satellite image 1137 has been downloaded
# No image exists for 1137. Image skipped.
# Satellite image 1138 has been downloaded
# Street view 1138 has been downloaded
# Satellite image 1139 has been downloaded
# Street view 1139 has been downloaded
# Satellite image 1140 has been downloaded
# Street view 1140 has been downloaded
# Satellite image 1141 has been downloaded
# Street view 1141 has been downloaded
# Satellite image 1142 has been downloaded
# Street view 1142 has been downloaded
# Satellite image 1143 has been downloaded
# Street view 1143 has been downloaded
# Satellite image 1144 has been downloaded
# Street view 1144 has been downloaded
# Satellite image 1145 has been downloaded
# Street view 1145 has been downloaded
# Satellite image 1146 has been downloaded
# Street view 1146 has been downloaded
# Satellite image 1147 has been downloaded
# Street view 1147 has been downloaded
# Satellite image 1148 has been downloaded
# Street view 1148 has been downloaded
# Satellite image 1149 has been downloaded
# Street view 1149 has been downloaded
# Satellite image 1150 has been downloaded
# Street view 1150 has been downloaded
# Satellite image 1151 has been downloaded
# Street view 1151 has been downloaded
# Satellite image 1152 has been downloaded
# Street view 1152 has been downloaded
# Satellite image 1153 has been downloaded
# Street view 1153 has been downloaded
# Satellite image 1154 has been downloaded
# Street view 1154 has been downloaded
# Satellite image 1155 has been downloaded
# Street view 1155 has been downloaded
# Satellite image 1156 has been downloaded
# Street view 1156 has been downloaded
# Satellite image 1157 has been downloaded
# Street view 1157 has been downloaded
# Satellite image 1158 has been downloaded
# Street view 1158 has been downloaded
# Satellite image 1159 has been downloaded
# Street view 1159 has been downloaded
# Satellite image 1160 has been downloaded
# Street view 1160 has been downloaded
# Satellite image 1161 has been downloaded
# Street view 1161 has been downloaded
# Satellite image 1162 has been downloaded
# Street view 1162 has been downloaded
# Satellite image 1163 has been downloaded
# Street view 1163 has been downloaded
# Satellite image 1164 has been downloaded
# Street view 1164 has been downloaded
# Satellite image 1165 has been downloaded
# Street view 1165 has been downloaded
# Satellite image 1166 has been downloaded
# Street view 1166 has been downloaded
# Satellite image 1167 has been downloaded
# Street view 1167 has been downloaded
# Satellite image 1168 has been downloaded
# Street view 1168 has been downloaded
# Satellite image 1169 has been downloaded
# Street view 1169 has been downloaded
# Satellite image 1170 has been downloaded
# Street view 1170 has been downloaded
# Satellite image 1171 has been downloaded
# Street view 1171 has been downloaded
# Satellite image 1172 has been downloaded
# Street view 1172 has been downloaded
# Satellite image 1173 has been downloaded
# Street view 1173 has been downloaded
# Satellite image 1174 has been downloaded
# Street view 1174 has been downloaded
# Satellite image 1175 has been downloaded
# Street view 1175 has been downloaded
# Satellite image 1176 has been downloaded
# Street view 1176 has been downloaded
# Satellite image 1177 has been downloaded
# Street view 1177 has been downloaded
# Satellite image 1178 has been downloaded
# Street view 1178 has been downloaded
# Satellite image 1179 has been downloaded
# Street view 1179 has been downloaded
# Satellite image 1180 has been downloaded
# Street view 1180 has been downloaded
# Satellite image 1181 has been downloaded
# Street view 1181 has been downloaded
# Satellite image 1182 has been downloaded
# Street view 1182 has been downloaded
# Satellite image 1183 has been downloaded
# Street view 1183 has been downloaded
# Satellite image 1184 has been downloaded
# Street view 1184 has been downloaded
# Satellite image 1185 has been downloaded
# Street view 1185 has been downloaded
# Satellite image 1186 has been downloaded
# Street view 1186 has been downloaded
# Satellite image 1187 has been downloaded
# Street view 1187 has been downloaded
# Satellite image 1188 has been downloaded
# Street view 1188 has been downloaded
# Satellite image 1189 has been downloaded
# Street view 1189 has been downloaded
# Satellite image 1190 has been downloaded
# Street view 1190 has been downloaded
# Satellite image 1191 has been downloaded
# Street view 1191 has been downloaded
# Satellite image 1192 has been downloaded
# Street view 1192 has been downloaded
# Satellite image 1193 has been downloaded
# Street view 1193 has been downloaded
# Satellite image 1194 has been downloaded
# Street view 1194 has been downloaded
# Satellite image 1195 has been downloaded
# Street view 1195 has been downloaded
# Satellite image 1196 has been downloaded
# Street view 1196 has been downloaded
# Satellite image 1198 has been downloaded
# Street view 1198 has been downloaded
# Satellite image 1199 has been downloaded
# Street view 1199 has been downloaded
# Satellite image 1200 has been downloaded
# Street view 1200 has been downloaded
# Satellite image 1201 has been downloaded
# Street view 1201 has been downloaded
# Satellite image 1202 has been downloaded
# Street view 1202 has been downloaded
# Satellite image 1203 has been downloaded
# Street view 1203 has been downloaded
# Satellite image 1204 has been downloaded
# Street view 1204 has been downloaded
# Satellite image 1205 has been downloaded
# Street view 1205 has been downloaded
# Satellite image 1206 has been downloaded
# Street view 1206 has been downloaded
# Satellite image 1207 has been downloaded
# Street view 1207 has been downloaded
# Satellite image 1208 has been downloaded
# Street view 1208 has been downloaded
# Satellite image 1209 has been downloaded
# Street view 1209 has been downloaded
# Satellite image 1210 has been downloaded
# Street view 1210 has been downloaded
# Satellite image 1211 has been downloaded
# Street view 1211 has been downloaded
# Satellite image 1212 has been downloaded
# Street view 1212 has been downloaded
# Satellite image 1213 has been downloaded
# Street view 1213 has been downloaded
# Satellite image 1214 has been downloaded
# Street view 1214 has been downloaded
# Satellite image 1215 has been downloaded
# Street view 1215 has been downloaded
# Satellite image 1216 has been downloaded
# Street view 1216 has been downloaded
# Satellite image 1217 has been downloaded
# Street view 1217 has been downloaded
# Satellite image 1218 has been downloaded
# Street view 1218 has been downloaded
# Satellite image 1219 has been downloaded
# Street view 1219 has been downloaded
# Satellite image 1220 has been downloaded
# Street view 1220 has been downloaded
# Satellite image 1221 has been downloaded
# Street view 1221 has been downloaded
# Satellite image 1223 has been downloaded
# Street view 1223 has been downloaded
# Satellite image 1224 has been downloaded
# Street view 1224 has been downloaded
# Satellite image 1225 has been downloaded
# Street view 1225 has been downloaded
# Satellite image 1226 has been downloaded
# Street view 1226 has been downloaded
# Satellite image 1227 has been downloaded
# Street view 1227 has been downloaded
# Satellite image 1228 has been downloaded
# Street view 1228 has been downloaded
# Satellite image 1229 has been downloaded
# Street view 1229 has been downloaded
# Satellite image 1230 has been downloaded
# Street view 1230 has been downloaded
# Satellite image 1231 has been downloaded
# Street view 1231 has been downloaded
# Satellite image 1232 has been downloaded
# Street view 1232 has been downloaded
# Satellite image 1233 has been downloaded
# No image exists for 1233. Image skipped.
# Satellite image 1234 has been downloaded
# Street view 1234 has been downloaded
# Satellite image 1235 has been downloaded
# Street view 1235 has been downloaded
# Satellite image 1237 has been downloaded
# Street view 1237 has been downloaded
# Satellite image 1238 has been downloaded
# Street view 1238 has been downloaded
# Satellite image 1241 has been downloaded
# Street view 1241 has been downloaded
# Satellite image 1242 has been downloaded
# Street view 1242 has been downloaded
# Satellite image 1243 has been downloaded
# Street view 1243 has been downloaded
# Satellite image 1244 has been downloaded
# Street view 1244 has been downloaded
# Satellite image 1245 has been downloaded
# Street view 1245 has been downloaded
# Satellite image 1246 has been downloaded
# No image exists for 1246. Image skipped.
# Satellite image 1247 has been downloaded
# No image exists for 1247. Image skipped.
# Satellite image 1249 has been downloaded
# Street view 1249 has been downloaded
# Satellite image 1250 has been downloaded
# Street view 1250 has been downloaded
# Satellite image 1251 has been downloaded
# Street view 1251 has been downloaded
# Satellite image 1252 has been downloaded
# Street view 1252 has been downloaded
# Satellite image 1253 has been downloaded
# Street view 1253 has been downloaded
# Satellite image 1254 has been downloaded
# Street view 1254 has been downloaded
# Satellite image 1255 has been downloaded
# Street view 1255 has been downloaded
# Satellite image 1256 has been downloaded
# Street view 1256 has been downloaded
# Satellite image 1257 has been downloaded
# Street view 1257 has been downloaded
# Satellite image 1258 has been downloaded
# Street view 1258 has been downloaded
# Satellite image 1259 has been downloaded
# Street view 1259 has been downloaded
# Satellite image 1260 has been downloaded
# Street view 1260 has been downloaded
# Satellite image 1261 has been downloaded
# Street view 1261 has been downloaded
# Satellite image 1262 has been downloaded
# Street view 1262 has been downloaded
# Satellite image 1263 has been downloaded
# Street view 1263 has been downloaded
# Satellite image 1264 has been downloaded
# Street view 1264 has been downloaded
# Satellite image 1265 has been downloaded
# Street view 1265 has been downloaded
# Satellite image 1266 has been downloaded
# Street view 1266 has been downloaded
# Satellite image 1267 has been downloaded
# Street view 1267 has been downloaded
# Satellite image 1268 has been downloaded
# Street view 1268 has been downloaded
# Satellite image 1269 has been downloaded
# Street view 1269 has been downloaded
# Satellite image 1270 has been downloaded
# Street view 1270 has been downloaded
# Satellite image 1271 has been downloaded
# Street view 1271 has been downloaded
# Satellite image 1272 has been downloaded
# Street view 1272 has been downloaded
# Satellite image 1273 has been downloaded
# Street view 1273 has been downloaded
# Satellite image 1274 has been downloaded
# Street view 1274 has been downloaded
# Satellite image 1275 has been downloaded
# Street view 1275 has been downloaded
# Satellite image 1281 has been downloaded
# No image exists for 1281. Image skipped.
# Satellite image 1306 has been downloaded
# No image exists for 1306. Image skipped.
# Satellite image 1307 has been downloaded
# ...
# Street view 200728 has been downloaded
# Satellite image 200730 has been downloaded
# Street view 200730 has been downloaded
# Satellite image 200731 has been downloaded
# Street view 200731 has been downloaded
# Satellite image 200732 has been downloaded
# Street view 200732 has been downloaded
# Satellite image 200733 has been downloaded
# Street view 200733 has been downloaded
# Satellite image 200734 has been downloaded
# Street view 200734 has been downloaded
# Satellite image 200735 has been downloaded
# Street view 200735 has been downloaded
# Satellite image 200736 has been downloaded
# Street view 200736 has been downloaded
# Satellite image 200737 has been downloaded
# Street view 200737 has been downloaded
# Satellite image 200739 has been downloaded
# Street view 200739 has been downloaded
# Satellite image 200741 has been downloaded
# Street view 200741 has been downloaded
# Satellite image 200742 has been downloaded
# Street view 200742 has been downloaded
# Satellite image 200743 has been downloaded
# Street view 200743 has been downloaded
# Satellite image 200744 has been downloaded
# Street view 200744 has been downloaded
# Satellite image 200746 has been downloaded
# Street view 200746 has been downloaded
# Satellite image 200747 has been downloaded
# No image exists for 200747. Image skipped.
# Satellite image 200748 has been downloaded
# Street view 200748 has been downloaded
# Satellite image 200749 has been downloaded
# Street view 200749 has been downloaded
# Satellite image 200750 has been downloaded
# Street view 200750 has been downloaded
# Satellite image 200751 has been downloaded
# Street view 200751 has been downloaded
# Satellite image 200753 has been downloaded
# Street view 200753 has been downloaded
# Satellite image 200754 has been downloaded
# Street view 200754 has been downloaded
# Satellite image 200755 has been downloaded
# Street view 200755 has been downloaded
# Satellite image 200756 has been downloaded
# Street view 200756 has been downloaded
# Satellite image 200757 has been downloaded
# Street view 200757 has been downloaded
# Satellite image 200758 has been downloaded
# Street view 200758 has been downloaded
# Satellite image 200760 has been downloaded
# Street view 200760 has been downloaded
# Satellite image 200761 has been downloaded
# No image exists for 200761. Image skipped.
# Satellite image 200762 has been downloaded
# Street view 200762 has been downloaded
# Satellite image 200763 has been downloaded
# Street view 200763 has been downloaded
# Satellite image 200764 has been downloaded
# Street view 200764 has been downloaded
# Satellite image 200765 has been downloaded
# Street view 200765 has been downloaded
# Satellite image 200766 has been downloaded
# Street view 200766 has been downloaded
# Satellite image 200770 has been downloaded
# Street view 200770 has been downloaded
# Satellite image 200771 has been downloaded
# No image exists for 200771. Image skipped.
# Satellite image 200787 has been downloaded
# No image exists for 200787. Image skipped.
# Satellite image 200799 has been downloaded
# No image exists for 200799. Image skipped.
# Satellite image 200801 has been downloaded
# No image exists for 200801. Image skipped.
# Satellite image 200937 has been downloaded
# Street view 200937 has been downloaded
# Satellite image 200982 has been downloaded
# Street view 200982 has been downloaded
# Satellite image 200995 has been downloaded
# Street view 200995 has been downloaded
# Satellite image 200996 has been downloaded
# Street view 200996 has been downloaded
# Satellite image 201006 has been downloaded
# No image exists for 201006. Image skipped.
# Satellite image 201009 has been downloaded
# Street view 201009 has been downloaded
# Satellite image 201015 has been downloaded
# Street view 201015 has been downloaded
# Satellite image 201023 has been downloaded
# Street view 201023 has been downloaded
# Satellite image 201025 has been downloaded
# Street view 201025 has been downloaded
# Satellite image 201027 has been downloaded
# Street view 201027 has been downloaded
# Satellite image 201031 has been downloaded
# Street view 201031 has been downloaded
# Satellite image 201036 has been downloaded
# Street view 201036 has been downloaded
# Satellite image 201039 has been downloaded
# Street view 201039 has been downloaded
# Satellite image 201042 has been downloaded
# No image exists for 201042. Image skipped.
# Satellite image 201046 has been downloaded
# Street view 201046 has been downloaded
# Satellite image 201047 has been downloaded
# Street view 201047 has been downloaded
# Satellite image 201048 has been downloaded
# Street view 201048 has been downloaded
# Satellite image 201049 has been downloaded
# Street view 201049 has been downloaded
# Satellite image 201050 has been downloaded
# Street view 201050 has been downloaded
# Satellite image 201051 has been downloaded
# Street view 201051 has been downloaded
# Satellite image 201056 has been downloaded
# Street view 201056 has been downloaded
# Satellite image 201060 has been downloaded
# Street view 201060 has been downloaded
# Satellite image 201063 has been downloaded
# Street view 201063 has been downloaded
# Satellite image 201064 has been downloaded
# No image exists for 201064. Image skipped.
# Satellite image 201067 has been downloaded
# Street view 201067 has been downloaded
# Satellite image 201070 has been downloaded
# Street view 201070 has been downloaded
# Satellite image 201076 has been downloaded
# Street view 201076 has been downloaded
# Satellite image 201085 has been downloaded
# Street view 201085 has been downloaded
# Satellite image 201091 has been downloaded
# Street view 201091 has been downloaded
# Satellite image 201093 has been downloaded
# Street view 201093 has been downloaded
# Satellite image 201094 has been downloaded
# Street view 201094 has been downloaded
# Satellite image 201105 has been downloaded
# Street view 201105 has been downloaded
# Satellite image 201254 has been downloaded
# Street view 201254 has been downloaded
# Satellite image 201264 has been downloaded
# No image exists for 201264. Image skipped.
# Satellite image 201269 has been downloaded
# Street view 201269 has been downloaded
# Satellite image 201275 has been downloaded
# No image exists for 201275. Image skipped.
# Satellite image 201280 has been downloaded
# Street view 201280 has been downloaded
# Satellite image 201281 has been downloaded
# Street view 201281 has been downloaded
# Satellite image 201289 has been downloaded
# No image exists for 201289. Image skipped.
# Satellite image 201291 has been downloaded
# No image exists for 201291. Image skipped.
# Satellite image 201293 has been downloaded
# Street view 201293 has been downloaded
# Satellite image 201295 has been downloaded
# Street view 201295 has been downloaded
# Satellite image 201296 has been downloaded
# Street view 201296 has been downloaded
# Satellite image 201299 has been downloaded
# Street view 201299 has been downloaded
# Satellite image 201301 has been downloaded
# Street view 201301 has been downloaded
# Satellite image 201302 has been downloaded
# Street view 201302 has been downloaded
# Satellite image 201303 has been downloaded
# Street view 201303 has been downloaded
# Satellite image 201304 has been downloaded
# Street view 201304 has been downloaded
# Satellite image 201305 has been downloaded
# Street view 201305 has been downloaded
# Satellite image 201306 has been downloaded
# Street view 201306 has been downloaded
# Satellite image 201307 has been downloaded
# Street view 201307 has been downloaded
# Satellite image 201308 has been downloaded
# Street view 201308 has been downloaded
# Satellite image 201309 has been downloaded
# Street view 201309 has been downloaded
# Satellite image 201310 has been downloaded
# Street view 201310 has been downloaded
# Satellite image 201311 has been downloaded
# Street view 201311 has been downloaded
# Satellite image 201312 has been downloaded
# Street view 201312 has been downloaded
# Satellite image 201313 has been downloaded
# Street view 201313 has been downloaded
# Satellite image 201314 has been downloaded
# Street view 201314 has been downloaded
# Satellite image 201315 has been downloaded
# Street view 201315 has been downloaded
# Satellite image 201316 has been downloaded
# No image exists for 201316. Image skipped.
# Satellite image 201317 has been downloaded
# Street view 201317 has been downloaded
# Satellite image 201318 has been downloaded
# Street view 201318 has been downloaded
# Satellite image 201325 has been downloaded
# Street view 201325 has been downloaded
# Satellite image 201326 has been downloaded
# Street view 201326 has been downloaded
# Satellite image 201328 has been downloaded
# Street view 201328 has been downloaded
# Satellite image 201329 has been downloaded
# Street view 201329 has been downloaded
# Satellite image 201330 has been downloaded
# Street view 201330 has been downloaded
# Satellite image 201331 has been downloaded
# Street view 201331 has been downloaded
# Satellite image 201332 has been downloaded
# Street view 201332 has been downloaded
# Satellite image 201333 has been downloaded
# Street view 201333 has been downloaded
# Satellite image 201334 has been downloaded
# No image exists for 201334. Image skipped.
# Satellite image 201335 has been downloaded
# Street view 201335 has been downloaded
# Satellite image 201336 has been downloaded
# No image exists for 201336. Image skipped.
# Satellite image 201337 has been downloaded
# Street view 201337 has been downloaded
# Satellite image 201339 has been downloaded
# No image exists for 201339. Image skipped.
# Satellite image 201340 has been downloaded
# Street view 201340 has been downloaded
# Satellite image 201341 has been downloaded
# No image exists for 201341. Image skipped.
# Satellite image 201342 has been downloaded
# Street view 201342 has been downloaded
# Satellite image 201344 has been downloaded
# No image exists for 201344. Image skipped.
# Satellite image 201345 has been downloaded
# No image exists for 201345. Image skipped.
# Satellite image 201346 has been downloaded
# Street view 201346 has been downloaded
# Satellite image 201354 has been downloaded
# Street view 201354 has been downloaded
# Satellite image 201356 has been downloaded
# Street view 201356 has been downloaded
# Satellite image 201357 has been downloaded
# Street view 201357 has been downloaded
# Satellite image 201358 has been downloaded
# Street view 201358 has been downloaded
# Satellite image 201500 has been downloaded
# Street view 201500 has been downloaded
# Satellite image 201502 has been downloaded
# Street view 201502 has been downloaded
# Satellite image 201504 has been downloaded
# Street view 201504 has been downloaded
# Satellite image 201515 has been downloaded
# Street view 201515 has been downloaded
# Satellite image 201522 has been downloaded
# Street view 201522 has been downloaded
# Satellite image 201527 has been downloaded
# Street view 201527 has been downloaded
# Satellite image 201536 has been downloaded
# Street view 201536 has been downloaded
# Satellite image 201541 has been downloaded
# Street view 201541 has been downloaded
# Satellite image 201543 has been downloaded
# Street view 201543 has been downloaded
# Satellite image 201545 has been downloaded
# Street view 201545 has been downloaded
# Satellite image 201549 has been downloaded
# Street view 201549 has been downloaded
# Satellite image 201565 has been downloaded
# Street view 201565 has been downloaded
# Satellite image 201575 has been downloaded
# Street view 201575 has been downloaded
# Satellite image 201577 has been downloaded
# No image exists for 201577. Image skipped.
# Satellite image 201580 has been downloaded
# No image exists for 201580. Image skipped.
# Satellite image 201581 has been downloaded
# No image exists for 201581. Image skipped.
# Satellite image 201582 has been downloaded
# Street view 201582 has been downloaded
# Satellite image 201584 has been downloaded
# Street view 201584 has been downloaded
# Satellite image 201587 has been downloaded
# Street view 201587 has been downloaded
# Satellite image 201591 has been downloaded
# Street view 201591 has been downloaded
# Satellite image 201592 has been downloaded
# Street view 201592 has been downloaded
# Satellite image 201593 has been downloaded
# Street view 201593 has been downloaded
# Satellite image 201595 has been downloaded
# Street view 201595 has been downloaded
# Satellite image 201597 has been downloaded
# Street view 201597 has been downloaded
# Satellite image 201598 has been downloaded
# Street view 201598 has been downloaded
# Satellite image 201599 has been downloaded
# Street view 201599 has been downloaded
# Satellite image 201600 has been downloaded
# Street view 201600 has been downloaded
# Satellite image 201601 has been downloaded
# Street view 201601 has been downloaded
# Satellite image 201602 has been downloaded
# Street view 201602 has been downloaded
# Satellite image 201603 has been downloaded
# Street view 201603 has been downloaded
# Satellite image 201604 has been downloaded
# Street view 201604 has been downloaded
# Satellite image 201605 has been downloaded
# Street view 201605 has been downloaded
# Satellite image 201606 has been downloaded
# Street view 201606 has been downloaded
# Satellite image 201607 has been downloaded
# Street view 201607 has been downloaded
# Satellite image 201608 has been downloaded
# Street view 201608 has been downloaded
# Satellite image 201609 has been downloaded
# Street view 201609 has been downloaded
# Satellite image 201616 has been downloaded
# Street view 201616 has been downloaded
# Satellite image 201623 has been downloaded
# Street view 201623 has been downloaded
# Satellite image 201624 has been downloaded
# Street view 201624 has been downloaded
# Satellite image 201629 has been downloaded
# Street view 201629 has been downloaded
# Satellite image 201631 has been downloaded
# No image exists for 201631. Image skipped.
# Satellite image 201763 has been downloaded
# Street view 201763 has been downloaded
# Satellite image 201796 has been downloaded
# Street view 201796 has been downloaded
# Satellite image 201803 has been downloaded
# Street view 201803 has been downloaded
# Satellite image 201822 has been downloaded
# No image exists for 201822. Image skipped.
# Satellite image 201825 has been downloaded
# Street view 201825 has been downloaded
# Satellite image 201834 has been downloaded
# Street view 201834 has been downloaded
# Satellite image 201838 has been downloaded
# No image exists for 201838. Image skipped.
# Satellite image 201839 has been downloaded
# No image exists for 201839. Image skipped.
# Satellite image 201844 has been downloaded
# Street view 201844 has been downloaded
# Satellite image 201848 has been downloaded
# Street view 201848 has been downloaded
# Satellite image 201853 has been downloaded
# Street view 201853 has been downloaded
# Satellite image 201859 has been downloaded
# Street view 201859 has been downloaded
# Satellite image 201860 has been downloaded
# Street view 201860 has been downloaded
# Satellite image 201864 has been downloaded
# Street view 201864 has been downloaded
# Satellite image 201874 has been downloaded
# Street view 201874 has been downloaded
# Satellite image 201876 has been downloaded
# Street view 201876 has been downloaded
# Satellite image 201877 has been downloaded
# Street view 201877 has been downloaded
# Satellite image 201880 has been downloaded
# Street view 201880 has been downloaded
# Satellite image 201881 has been downloaded
# Street view 201881 has been downloaded
# Satellite image 201884 has been downloaded
# Street view 201884 has been downloaded
# Satellite image 201891 has been downloaded
# No image exists for 201891. Image skipped.
# Satellite image 201892 has been downloaded
# No image exists for 201892. Image skipped.
# Satellite image 201894 has been downloaded
# No image exists for 201894. Image skipped.
# Satellite image 201896 has been downloaded
# Street view 201896 has been downloaded
# Satellite image 201964 has been downloaded
# Street view 201964 has been downloaded
# Satellite image 201988 has been downloaded
# Street view 201988 has been downloaded
# Satellite image 202095 has been downloaded
# Street view 202095 has been downloaded
# Satellite image 202203 has been downloaded
# Street view 202203 has been downloaded
# Satellite image 202206 has been downloaded
# Street view 202206 has been downloaded
# Satellite image 202270 has been downloaded
# Street view 202270 has been downloaded

# %%
df = pd.read_csv('../data/CS/Hubballi_Dhaward_Water_Consumption_All_NearRoad.csv')
df = df.dropna(subset=['permonthunitskl'])  # For buildings with known water consumption

# Create the consump_class column
bins = [0, 8, 15, 25, float('inf')]
labels = ['0-8', '8-15', '15-25', '>25']
df['consump_class'] = pd.cut(df['permonthunitskl'], bins=bins, labels=labels, right=False)
df.shape
# Out:
# (24366, 33)

# %%
# Check if satellite and street view images exist and add binary columns to the DataFrame
def check_image_availability(row, satellite_dir, street_dir):
    satellite_image_path = os.path.join(satellite_dir, f"{row['sl_no']}.jpg")
    street_image_path = os.path.join(street_dir, f"{row['sl_no']}.jpg")
    row['has_satellite_image'] = 1 if os.path.exists(satellite_image_path) else 0
    row['has_street_image'] = 1 if os.path.exists(street_image_path) else 0
    return row

# Define image directories
satellite_dir = '../data/raw/Hubballi_Satellite'
street_dir = '../data/raw/Hubballi_Original'

# Apply the function to each row in the DataFrame
df = df.apply(lambda row: check_image_availability(row, satellite_dir, street_dir), axis=1)

# Count the number of rows with satellite images
satellite_count = df['has_satellite_image'].sum()

# Count the number of rows with street view images
street_view_count = df['has_street_image'].sum()

print(f"Number of rows with satellite images: {satellite_count}")
print(f"Number of rows with street view images: {street_view_count}")
# Out:
# Number of rows with satellite images: 24366
# Number of rows with street view images: 19089
